# %%
import pandas as pd

# %%
data1=pd.read_csv("C:\\Users\\prakhar\\Downloads\\fifa21_male2.csv\\fifa21_male2.csv", encoding ="Latin")
# Out:
# C:\Users\prakhar\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (78) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data1.head()
# Out:
#    ID          Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2   G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis GarcÃ­a   37   71                  Spain      KAS Eupen   70   CM
# 2  27       J. Cole   33   71                England  Coventry City   71  CAM
# 3  36      D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41       Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png  ...
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png  ...
#
# ...

# %%
data1.describe()
# Out:
#                   ID           Age           OVA           BOV           POT  \
# count   17125.000000  17125.000000  17125.000000  17125.000000  17125.000000
# mean   219388.716204     25.272934     66.965022     67.900204     72.489810
# std     37499.197507      4.942665      6.864329      6.637538      5.769949
# min         2.000000     16.000000     38.000000     42.000000     47.000000
# 25%    204082.000000     21.000000     62.000000     64.000000     69.000000
# 50%    228961.000000     25.000000     67.000000     68.000000     72.000000
# 75%    243911.000000     29.000000     72.000000     72.000000     76.000000
# max    259105.000000     53.000000     93.000000     93.000000     95.000000
#
#              Growth     Attacking      Crossing     Finishing  \
# count  17125.000000  17125.000000  17125.000000  17125.000000
# mean       5.524788    258.537752     51.621314     47.956672
# std        5.787539     72.255687     17.875715     19.391547
# ...

# %%
lst_col = []
for i in data1.columns:
    lst_col.append(i)

print(lst_col)
# Out:
# ['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP', 'Position', 'Player Photo', 'Club Logo', 'Flag Photo', 'POT', 'Team & Contract', 'Height', 'Weight', 'foot', 'Growth', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause', 'Contract', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats', 'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Hits', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
# ...

# %%
data1.filter(like='G. Pasquale', axis=0)
print(data1)
# Out:
#            ID              Name  Age  OVA            Nationality  \
# 0           2       G. Pasquale   33   69                  Italy
# 1          16      Luis GarcÃ­a   37   71                  Spain
# 2          27           J. Cole   33   71                England
# 3          36          D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41           Iniesta   36   81                  Spain
# ...       ...               ...  ...  ...                    ...
# 17120  259088        A. Medioub   22   64                 France
# 17121  259090        W. Rickard   18   56                  Wales
# 17122  259091        C. Barrett   18   56                England
# 17123  259101   J. GazibegoviÄ   20   62     Bosnia Herzegovina
# 17124  259105  Pablo RodrÃ­guez   18   59                  Spain
#
#                 Club  BOV   BP      Position  \
# 0            Udinese   71  LWB            LM
# 1          KAS Eupen   70   CM    CM CAM CDM
# 2      Coventry City   71  CAM  CAM RM RW LM
# ...

# %%
is_italy =  data1['Nationality']=="Italy"

# %%
print(is_italy)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17120    False
# 17121    False
# 17122    False
# 17123    False
# 17124    False
# Name: Nationality, Length: 17125, dtype: bool

# %%
italyteam = data1[is_italy]

# %%
print(italyteam)
# Out:
#            ID          Name  Age  OVA Nationality             Club  BOV   BP  \
# 0           2   G. Pasquale   33   69       Italy          Udinese   71  LWB
# 23       1075  A. Del Piero   38   70       Italy        Sydney FC   74  CAM
# 24       1088      A. Nesta   37   73       Italy  Montreal Impact   72   CB
# 25       1109    P. Maldini   40   77       Italy            Milan   78   CB
# 26       1179     G. Buffon   42   82       Italy         Juventus   82   GK
# ...       ...           ...  ...  ...         ...              ...  ...  ...
# 16979  258733      A. Badan   22   59       Italy  Oldham Athletic   60  LWB
# 16981  258740     A. Padula   24   58       Italy    FC Basel 1893   58   LB
# 17061  258918     G. Crespi   19   49       Italy          Crotone   49   GK
# 17074  258946     M. Lovato   20   67       Italy    Hellas Verona   69   CB
# 17087  258976     F. Parisi   19   60       Italy           Empoli   61  LWB
#
# ...

# %%
is_England =  data1['Nationality']=="England"

# %%
Englandteam = data1[is_England]

# %%
print(Englandteam)
# Out:
#            ID           Name  Age  OVA Nationality                    Club  \
# 2          27        J. Cole   33   71     England           Coventry City
# 8         244  G. Neville  B   35   76     England       Manchester United
# 9         246     P. Scholes   37   80     England       Manchester United
# 10        249     P. Neville   35   74     England                 Everton
# 11        250     D. Beckham   37   78     England                     NaN
# ...       ...            ...  ...  ...         ...                     ...
# 17056  258904    J. Flanagan   17   55     England        Northampton Town
# 17095  259031       L. Delap   17   61     England         Manchester City
# 17096  259032       T. Jenks   18   54     England  Brighton & Hove Albion
# 17105  259063      R. Fenlon   18   53     England      Accrington Stanley
# 17122  259091     C. Barrett   18   56     England                 Burnley
#
#        BOV   BP      Position  \
# 2       71  CAM  CAM RM RW LM
# ...

# %%
Ages = [i for i in range(16,43,1)]
filterageseng=Englandteam.Age.isin(Ages)
print(filterageseng)
# Out:
# 2        True
# 8        True
# 9        True
# 10       True
# 11       True
#          ...
# 17056    True
# 17095    True
# 17096    True
# 17105    True
# 17122    True
# Name: Age, Length: 1707, dtype: bool

# %%
EnglandteamAges = Englandteam[filterageseng]

# %%
print(EnglandteamAges)
# Out:
#            ID           Name  Age  OVA Nationality                    Club  \
# 2          27        J. Cole   33   71     England           Coventry City
# 8         244  G. Neville  B   35   76     England       Manchester United
# 9         246     P. Scholes   37   80     England       Manchester United
# 10        249     P. Neville   35   74     England                 Everton
# 11        250     D. Beckham   37   78     England                     NaN
# ...       ...            ...  ...  ...         ...                     ...
# 17056  258904    J. Flanagan   17   55     England        Northampton Town
# 17095  259031       L. Delap   17   61     England         Manchester City
# 17096  259032       T. Jenks   18   54     England  Brighton & Hove Albion
# 17105  259063      R. Fenlon   18   53     England      Accrington Stanley
# 17122  259091     C. Barrett   18   56     England                 Burnley
#
#        BOV   BP      Position  \
# 2       71  CAM  CAM RM RW LM
# ...

# %%
OVASeng = [i for i in range(71,93,1)]
filterOVAseng=EnglandteamAges.OVA.isin(OVASeng)
print(filterOVAseng)
# Out:
# 2         True
# 8         True
# 9         True
# 10        True
# 11        True
#          ...
# 17056    False
# 17095    False
# 17096    False
# 17105    False
# 17122    False
# Name: OVA, Length: 1706, dtype: bool

# %%
EnglandteamOVA = EnglandteamAges[filterOVAseng]

EnglandteamOVA.to_csv("F:\england teams\Enagland_11.csv")

# %%
EnglandteamOVA['new'] = EnglandteamOVA['Contract']
# Out:
# <ipython-input-24-5903c5b08f75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EnglandteamOVA['new'] = EnglandteamOVA['Contract']

# %%
EnglandteamOVA['new']
# Out:
# 2         2016 ~ 2020
# 8         1991 ~ 2011
# 9         1993 ~ 2013
# 10        2005 ~ 2013
# 11       England Free
#              ...
# 12654     2018 ~ 2024
# 12809     2018 ~ 2022
# 13102     2020 ~ 2024
# 13576     2018 ~ 2023
# 13720     2018 ~ 2025
# Name: new, Length: 281, dtype: object

# %%
temp_1 =[]
for i in EnglandteamOVA['new']:
    
    if i == "England Free":
        i = None
        temp_1.append(i)
    elif (i.find("Loan")) >= 0:
        i = "50000"
        temp_1.append(i)
    else:
        print(i.split("~"))
        temp = i.split(" ~ ")
        i = temp[1]
        temp_1.append(i)
# Out:
# ['2016 ', ' 2020']
# ['1991 ', ' 2011']
# ['1993 ', ' 2013']
# ['2005 ', ' 2013']
# ['2010 ', ' 2011']
# ['2012 ', ' 2013']
# ['1996 ', ' 2013']
# ['2015 ', ' 2023']
# ['2014 ', ' 2015']
# ['2013 ', ' 2017']
# ['2011 ', ' 2012']
# ['2017 ', ' 2018']
# ['2015 ', ' 2023']
# ['2006 ', ' 2018']
# ['2020 ', ' 2021']
# ['1998 ', ' 2012']
# ['2019 ', ' 2019']
# ['2019 ', ' 2021']
# ['2017 ', ' 2020']
# ['2020 ', ' 2021']
# ['2016 ', ' 2018']
# ['2012 ', ' 2020']
# ['2015 ', ' 2018']
# ['2017 ', ' 2017']
# ['2015 ', ' 2022']
# ['2020 ', ' 2022']
# ['2020 ', ' 2022']
# ['2004 ', ' 2021']
# ['2020 ', ' 2021']
# ['2016 ', ' 2024']
# ['2014 ', ' 2021']
# ['2000 ', ' 2016']
# ['2015 ', ' 2022']
# ['2018 ', ' 2022']
# ['2019 ', ' 2021']
# ['2007 ', ' 2020']
# ['2020 ', ' 2020']
# ['2019 ', ' 2021']
# ['2018 ', ' 2021']
# ['2020 ', ' 2022']
# ['2007 ', ' 2021']
# ['2012 ', ' 2020']
# ['2015 ', ' 2021']
# ['2017 ', ' 2021']
# ['2014 ', ' 2020']
# ['2019 ', ' 2021']
# ['2017 ', ' 2020']
# ...

# %%
temp_1
# Out:
# ['2020',
#  '2011',
#  '2013',
#  '2013',
#  None,
#  '2011',
#  '2013',
#  '2013',
#  '2023',
#  '2015',
#  '2017',
#  '2012',
#  '2018',
#  '2023',
#  '2018',
#  '2021',
#  '2012',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2018',
#  '2020',
#  '2018',
#  '2017',
#  '2022',
#  '2022',
#  '50000',
#  '2022',
#  '2021',
#  '2021',
#  '2024',
#  '2021',
#  '2016',
#  '2022',
#  '2022',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '50000',
#  '2022',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2020',
#  '2022',
#  '2022',
#  '2020',
#  '50000',
#  '2022',
#  '2021',
#  '2022',
#  '2020',
#  '2023',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2021',
#  '2023',
#  '2021',
#  '2023',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2023',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2024',
#  '2021',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
# ...

# %%
import re
p = re.compile(r"[0-9]+\s\~\s[0-9]+")
print(p.match("2015 ~ 2121"))
# Out:
# <re.Match object; span=(0, 11), match='2015 ~ 2121'>

# %%
EnglandteamOVA['new'] = temp_1
# Out:
# <ipython-input-29-50fd18f9b056>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EnglandteamOVA['new'] = temp_1

# %%
EnglandteamOVA.head()
EnglandteamOVA['new'] = pd.to_numeric(EnglandteamOVA['new'])
# Out:
# <ipython-input-30-d77b3cfa376e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EnglandteamOVA['new'] = pd.to_numeric(EnglandteamOVA['new'])

# %%
EnglandteamOVA
# Out:
#            ID           Name  Age  OVA Nationality               Club  BOV  \
# 2          27        J. Cole   33   71     England      Coventry City   71
# 8         244  G. Neville  B   35   76     England  Manchester United   78
# 9         246     P. Scholes   37   80     England  Manchester United   82
# 10        249     P. Neville   35   74     England            Everton   75
# 11        250     D. Beckham   37   78     England                NaN   77
# ...       ...            ...  ...  ...         ...                ...  ...
# 12654  243414    B. Williams   19   75     England  Manchester United   75
# 12809  243828   M. Longstaff   20   72     England   Newcastle United   74
# 13102  244591       J. Bogle   19   72     England   Sheffield United   73
# 13576  246147   M. Greenwood   18   77     England  Manchester United   78
# 13720  246669        B. Saka   18   75     England            Arsenal   76
#
# ...

# %%
newno=[i for i in range(2019,50001)]
filterEnglandteamOVA=EnglandteamOVA.new.isin(newno)
print(filterEnglandteamOVA)
# Out:
# 2         True
# 8        False
# 9        False
# 10       False
# 11       False
#          ...
# 12654     True
# 12809     True
# 13102     True
# 13576     True
# 13720     True
# Name: new, Length: 281, dtype: bool

# %%
england1 = EnglandteamOVA[filterEnglandteamOVA]
england1
# Out:
#            ID          Name  Age  OVA Nationality               Club  BOV  \
# 2          27       J. Cole   33   71     England      Coventry City   71
# 68       5471    F. Lampard   38   78     England   New York City FC   76
# 122     13743    S. Gerrard   36   81     England          LA Galaxy   79
# 229     50542      J. Defoe   37   73     England         Rangers FC   73
# 236     51257     P. Crouch   37   72     England            Burnley   71
# ...       ...           ...  ...  ...         ...                ...  ...
# 12654  243414   B. Williams   19   75     England  Manchester United   75
# 12809  243828  M. Longstaff   20   72     England   Newcastle United   74
# 13102  244591      J. Bogle   19   72     England   Sheffield United   73
# 13576  246147  M. Greenwood   18   77     England  Manchester United   78
# 13720  246669       B. Saka   18   75     England            Arsenal   76
#
#         BP      Position                                       Player Photo  \
# ...

# %%
lst_clubs = []
for i in data1.Club:
    lst_clubs.append(i)

print(lst_clubs)
# Out:
# ['Udinese', 'KAS Eupen', 'Coventry City', 'Sunderland', 'Vissel Kobe', 'Alemannia Aachen', 'FenerbahÃ§e SK', 'Manchester United', 'Manchester United', 'Manchester United', 'Everton', nan, 'LA Galaxy', 'Newcastle United', 'FC Bayern MÃ¼nchen', 'Milton Keynes Dons', 'Hull City', 'Pohang Steelers', 'Leicester City', 'VfB Stuttgart', 'Hungary', 'FC Anzhi Makhachkala', 'Inter', 'Sydney FC', 'Montreal Impact', 'Milan', 'Juventus', 'Juventus', 'Parma', 'Milan', 'Milan', 'CF Estrela da Amadora', 'Roma', 'Botafogo', 'Manchester City', 'FC Barcelona', nan, 'Paris Saint-Germain', 'Paris Saint-Germain', 'Manchester United', 'Ipswich Town', 'Ajax', 'Manchester City', 'Borussia Dortmund', 'Bolton Wanderers', 'SL Benfica', 'Stoke City', 'Newport County', 'Burton Albion', 'Aston Villa', 'Rio Ave FC', 'New York Red Bulls', 'SD Ponferradina', 'Reading', 'Portugal', 'Bayer 04 Leverkusen', 'Internacional', 'Bayer 04 Leverkusen', 'RCD Espanyol', 'Cracovia', 'FC Sion', 'New York Red Bulls', 'Milan', 'Lecc
# ...

# %%
totalclubs=len(lst_clubs)
print(totalclubs)
# Out:
# 17125

# %%
teams=['Hellas Verona', 'Milan', 'Cagliari', 'Bologna', 'Parma', 'Fiorentina', 'Spal', 'Empoli', 'Juventus', 'Napoli', 'Lazio', 'Atalanta', 'Fiorentina', 'Inter', 'Roma', 'Udinese', 'Crotone', 'Genoa', 'Benevento', 'Spezia', 'Burnley', 'West Bromwich', 'Brighton & Hove Albion', 'Leeds United', 'Wolverhampton Wanderers', 'Southampton', 'West Ham United', 'Chelsea', 'Tottenham Hotspur', 'Crystal Palace', 'Arsenal', 'Bournemouth', 'Cardiff City', 'Everton', 'Newcastle United', 'Manchester City', 'Aston Villa', 'Liverpool', 'Fulham', 'Manchester United', 'Leicester City', 'Paris Saint-Germain', 'Olympique de Marseille', 'Olympique Lyonnais', 'LOSC Lille', 'Stade Rennais FC', 'AS Monaco', 'Montpellier HSC', 'OGC Nice', 'Angers SCO', 'FC Metz', 'Racing Club de Lens', 'FC Girondins de Bordeaux', 'Stade Brestois 29', 'FC Nantes', 'Stade de Reims', 'FC Lorient', 'RC Strasbourg Alsace', 'Dijon FCO', 'FC Bayern MÃ¼nchen', 'RB Leipzig', 'Borussia Dortmund', 'Bayer 04 Leverkusen', 'FC Union Berlin', 'VfL Wolfsburg', 'Borussia MÃ¶nchengladbach', 'VfB Stuttgart', 'SV Werder Bremen', 'FC Augsburg', 'Eintracht Frankfurt', 'Hertha BSC', 'TSG 1899 Hoffenheim', 'SC Freiburg', 'DSC Arminia Bielefeld', 'FC KÃ¶ln', 'FC Schalke 04', 'FSV Mainz 05', 'Real Sociedad', 'Villarreal CF', 'AtlÃ©tico Madrid', 'Real Madrid', 'Granada CF', 'CÃ¡diz CF', 'Real Betis', 'FC Barcelona', 'Norwich City', 'Valencia CF', 'Getafe CF', 'Elche CF', 'Sevilla FC', 'CA Osasuna', 'Athletic Club de Bilbao', 'Deportivo AlavÃ©s', 'SD Eibar', 'RC Celta', 'Levante UD', 'Real Valladolid CF', 'SD Huesca', 'Sporting Club de Bastia', 'Sporting CP', 'SC Braga', 'SL Benfica', 'FC Porto', 'Rio Ave FC', 'Ajax', 'Vitesse', 'PSV', 'Feyenoord', 'FC Twente', 'SC Heerenveen', 'FC Groningen', 'AZ Alkmaar', 'FC Utrecht', 'Alanyaspor', 'FenerbahÃ§e SK', 'Galatasaray SK', 'Medipol BaÅŸakÅŸehir FK', 'Fatih KaragÃ¼mrÃ¼k S.K.', 'Dynamo Kyiv', 'Shakhtar Donetsk']

# %%
england2=england1.Club.isin(teams)
england = england1[england2]
england
# Out:
#            ID          Name  Age  OVA Nationality               Club  BOV  \
# 236     51257     P. Crouch   37   72     England            Burnley   71
# 408    135883    S. Francis   34   74     England        Bournemouth   74
# 442    138412     J. Milner   34   80     England          Liverpool   81
# 627    150724       J. Hart   33   75     England  Tottenham Hotspur   75
# 646    152879      M. Noble   33   75     England    West Ham United   75
# ...       ...           ...  ...  ...         ...                ...  ...
# 12613  243282     D. McNeil   20   78     England            Burnley   79
# 12654  243414   B. Williams   19   75     England  Manchester United   75
# 12809  243828  M. Longstaff   20   72     England   Newcastle United   74
# 13576  246147  M. Greenwood   18   77     England  Manchester United   78
# 13720  246669       B. Saka   18   75     England            Arsenal   76
#
#         BP   Position                                       Player Photo  ...  \
# ...

# %%
england.to_csv("F:\england teams\ENGALANDt159.csv")

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
x = england['OVA']
plt.hist(x,bins=10)
plt.show()
england.mean()
# Out:
# ID                  204663.264151
# Age                     26.150943
# OVA                     76.352201
# BOV                     77.163522
# POT                     79.830189
# Growth                   3.477987
# Attacking              295.691824
# Crossing                61.893082
# Finishing               53.339623
# Heading Accuracy        60.559748
# Short Passing           70.522013
# Volleys                 49.377358
# Skill                  310.836478
# Dribbling               66.905660
# Curve                   57.823899
# FK Accuracy             50.861635
# Long Passing            64.855346
# Ball Control            70.389937
# Movement               342.735849
# Acceleration            67.132075
# Sprint Speed            67.597484
# Agility                 67.182390
# Reactions               74.301887
# Balance                 66.522013
# Power                  329.176101
# Shot Power              66.761006
# Jumping                 68.383648
# ...

# %%
lineup=['433','451','442']

# %%
Bestposition = []
for i in england.BP:
    if i not in Bestposition:
        Bestposition.append(i)

print(Bestposition)

# %%
import statistics
listCB=['CB']

englandCB = england[england['BP'].isin(listCB)] 
meanCB = statistics.mean(englandCB['OVA']) 
englandCB=englandCB[englandCB['OVA']>meanCB]

englandCB=englandCB.sort_values(by='OVA', ascending=False, na_position='first')
englandCB

# %%
listCDM=['CDM']

englandCDM = england[england['BP'].isin(listCDM)] 
meanCDM = statistics.mean(englandCDM['OVA']) 
englandCDM=englandCDM[englandCDM['OVA']>meanCDM]

englandCDM=englandCDM.sort_values(by='OVA', ascending=False, na_position='first')
englandCDM

# %%
listCM=['CM']

englandCM = england[england['BP'].isin(listCM)] 
meanCM = statistics.mean(englandCM['OVA']) 
englandCM=englandCM[englandCM['OVA']>meanCM]

englandCM=englandCM.sort_values(by='OVA', ascending=False, na_position='first')
englandCM

# %%
listCAM=['CAM']

englandCAM = england[england['BP'].isin(listCAM)] 
meanCAM = statistics.mean(englandCAM['OVA']) 
englandCAM=englandCAM[englandCAM['OVA']>meanCAM]

englandCAM=englandCAM.sort_values(by='OVA', ascending=False, na_position='first')
englandCAM

# %%
listGK=['GK']

englandGK = england[england['BP'].isin(listGK)] 
meanGK = statistics.mean(englandGK['OVA']) 
englandGK=englandGK[englandGK['OVA']>meanGK]
englandGK=englandGK.sort_values(by='OVA', ascending=False, na_position='first')
englandGK

# %%
listLM=['LM']

englandLM = england[england['BP'].isin(listLM)] 
meanLM = statistics.mean(englandLM['OVA']) 
englandLM=englandLM[englandLM['OVA']>meanLM]

englandLM=englandLM.sort_values(by='OVA', ascending=False, na_position='first')
englandLM

# %%
listRM=['RM']

englandRM = england[england['BP'].isin(listRM)] 
meanRM = statistics.mean(englandRM['OVA']) 
englandRM=englandRM[englandRM['OVA']>meanRM]

englandRM=englandRM.sort_values(by='OVA', ascending=False, na_position='first')
englandRM

# %%
listRB=['RB']

englandRB = england[england['BP'].isin(listRB)] 
meanRB = statistics.mean(englandRB['OVA']) 
englandRB=englandRB[englandRB['OVA']>meanRB]

englandRB=englandRB.sort_values(by='OVA', ascending=False, na_position='first')
englandRB

# %%
listLB=['LB']

englandLB = england[england['BP'].isin(listLB)] 
meanLB = statistics.mean(englandLB['OVA']) 
englandLB=englandLB[englandLB['OVA']>meanLB]

englandLB=englandLB.sort_values(by='OVA', ascending=False, na_position='first')
englandLB

# %%
listLWB=['LWB']

englandLWB = england[england['BP'].isin(listLWB)] 
meanLWB = statistics.mean(englandLWB['OVA']) 
englandLWB=englandLWB[englandLWB['OVA']>=meanLWB]

englandLWB=englandLWB.sort_values(by='OVA', ascending=False, na_position='first')
englandLWB

# %%
listLW=['LW']

englandLW = england[england['BP'].isin(listLW)] 
meanLW = statistics.mean(englandLW['OVA']) 
englandLW=englandLW[englandLW['OVA']>=0]

englandLW=englandLW.sort_values(by='OVA', ascending=False, na_position='first')
englandLW

# %%
listRW=['RW']

englandRW = england[england['BP'].isin(listRW)] 
meanRW = statistics.mean(englandRW['OVA'])
 
englandRW=englandRW[englandRW['OVA']>=0]
englandRW=englandRW.sort_values(by='OVA', ascending=False, na_position='first')
englandRW

# %%
listRWB=['RWB']

englandRWB = england[england['BP'].isin(listRWB)] 
meanRWB = statistics.mean(englandRWB['OVA']) 
englandRWB=englandRWB[englandRWB['OVA']>=0]
englandRWB=englandRWB.sort_values(by='OVA', ascending=False, na_position='first')





listST=['ST']
englandST= england[england['BP'].isin(listST )] 
meanST  = statistics.mean(englandST ['OVA']) 
englandST =englandST [englandST ['OVA']>=meanST]
englandST =englandST .sort_values(by='OVA', ascending=False, na_position='first')

    
    
    








england_dof=pd.concat([englandST,englandLW,englandRW,englandLM,englandRM,englandCM,englandCAM,englandCB,englandLB,englandRB,englandLWB,englandRWB,englandCDM,englandGK])
england_dof.to_csv("F:\england teams\ENGALANDtop70.csv")

# %%
england_dof
# Out:
#           ID              Name  Age  OVA Nationality               Club  BOV  \
# 3961  202126           H. Kane   26   88     England  Tottenham Hotspur   88
# 5046  208830          J. Vardy   33   86     England     Leicester City   86
# 3169  195859           D. Ings   27   80     England        Southampton   80
# 7026  221479  D. Calvert-Lewin   23   79     England            Everton   81
# 2619  190717        M. Antonio   30   78     England    West Ham United   78
# ...      ...               ...  ...  ...         ...                ...  ...
# 4458  204935       J. Pickford   26   81     England            Everton   81
# 9709  233306      D. Henderson   23   80     England  Manchester United   80
# 870   163264         T. Heaton   34   78     England        Aston Villa   78
# 2396  189324       A. McCarthy   30   77     England        Southampton   77
# 1209  172203        F. Forster   32   76     England        Southampton   76
#
# ...

# %%
meantop70 = statistics.mean(england_dof ['OVA'])

# %%
print(meantop70)
print((meanCDM+meanCAM+meanCM+meanLM+meanRM)/5)
print((meanCB+meanGK+meanRB+meanLB)/4)
print((meanRW+meanLW+meanST)/3)
print((meanLWB+meanRWB)/2)
# Out:
# 79.13698630136986
# 76.18602564102564
# 76.41666666666667
# 79.66666666666667
# 75.125

# %%
for i in england_dof:
    print(i)

# %%
list442=[]
for i in england_dof['OVA']:
    if i=='ST':
        for k in range(1,2):
            list442.append(england_dof[])
